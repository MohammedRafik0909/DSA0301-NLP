# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedRafik0909/DSA0301-NLP/blob/main/exp_3_morphological_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def morphological_analysis(text):
    # Tokenize the input text into words
    words = word_tokenize(text)

    for word in words:
        # Perform Part-of-Speech tagging to determine the word's grammatical category
        pos_tags = nltk.pos_tag([word])

        for token, pos in pos_tags:
            print(f"Word: {token}")
            print(f"Part-of-Speech (POS) Tag: {pos}")

            # Perform morphological analysis using WordNet
            synsets = wordnet.synsets(token)
            if synsets:
                # Display the word's meanings (synsets) and example usage
                for synset in synsets:
                    print(f"Synset: {synset.name()}")
                    print(f"Definition: {synset.definition()}")
                    print(f"Examples: {synset.examples()}")
            else:
                print("No synsets found for this word.")
            print("\n")

if __name__ == "__main__":
    input_text = "I enjoy swimming in the ocean. Swimmers need to swim regularly."
    morphological_analysis(input_text)
# Out:
# Word: I
# Part-of-Speech (POS) Tag: PRP
# Synset: iodine.n.01
# Definition: a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks)
# Examples: []
# Synset: one.n.01
# Definition: the smallest whole number or a numeral representing this number
# Examples: ['he has the one but will need a two and three to go with it', 'they had lunch at one']
# Synset: i.n.03
# Definition: the 9th letter of the Roman alphabet
# Examples: []
# Synset: one.s.01
# Definition: used of a single unit or thing; not two or more
# Examples: ["`ane' is Scottish"]
#
#
# Word: enjoy
# Part-of-Speech (POS) Tag: NN
# Synset: enjoy.v.01
# Definition: derive or receive pleasure from; get enjoyment from; take pleasure in
# Examples: ['She relished her fame and basked in her glory']
# Synset: enjoy.v.02
# Definition: have benefit from
# Examples: ['enjoy privileges']
# Synset: love.v.02
# ...
